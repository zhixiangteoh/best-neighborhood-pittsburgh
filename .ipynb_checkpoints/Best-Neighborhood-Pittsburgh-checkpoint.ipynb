# %% [markdown]
# # Best Neighborhood in Pittsburgh...?

# %% [markdown]
# ## Introduction:
#
# This small project aims to use a simple metric to make an informed and comprehensive analysis of the various neighborhoods in Pittsburgh to ultimately determine which neighborhood is the best, utilizing Python *pandas dataframes* and geopandas as the primary tools for data analysis.
#
# ## Metric:
#
# My metric to determine which neighborhood is the best in Pittsburgh is **Bus Stops**. In order to comprehensively evaluate this and analyze this, I will be comparing both Bus Stop *Density* and Bus Stop *Usage* and *Ridership* for each neighborhood. For the former I will pull data from the Port Authority Transit Stops dataset. For the latter I will analyze data from the Bus Stop Usage dataset and Port Authority Monthly Average Ridership dataset. The 'scoring table' will be similar to the following:
#
# | Neighborhood      | Bus Stop Density  | Bus Stop Usage | Average Ridership |
# | ----------------- | ----------------- | -------------- | ----------------- |
# | Westwood          |                   |                |                   |
# | 31st ward         |                   |                |                   |
# | Arlington         |                   |                |                   |
# | Allegheny Center  |                   |                |                   |
# | Allegheny West    |                   |                |                   |
# | ...               |                   |                |                   |
# | Woods Run- Halls Grove |              |                |                   |
#
# As you can tell, there will be some difficulties in deciding which neighborhood really is the best neighborhood just from looking at this table alone! How are we going to decide *whether* and *when* Bus Stop Density should outweigh Bus Stop Usage, and vice versa? And **how** do we even calculate Bus Stop Density, if we are not immediately given the numbers? Let's dive into the data to find out!
#
# ## Best Neighborhood:
#
# <span style="color:#1b4537"><b>Friendship</b></span> is the best **bus stop** neighborhood in Pittsburgh. After some careful data analysis and weighing of the different factors according to the above table, results show that Friendship ranks a cut above the rest of the neighborhoods overall.

# %% [markdown]
# ## Conclusion:
#
# Is this what we expected (or should expect)? Let's briefly look at *Neighborhood Satisfaction* data to see which neighborhood's residents are most satisfied with their transportation system.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
satisfaction = pd.read_csv("https://data.wprdc.org/datastore/dump/88da41a0-9386-438d-8d27-7a8f7cea3069")

satisfaction.rename(columns={'neighborhood':'Neighborhood'}, inplace=True)
satisfaction = satisfaction[['Neighborhood','public_transportation_satisfied','public_transportation_dissatisfied','public_transportation_neither']]

satisfaction_ranked = satisfaction.sort_values(by="public_transportation_satisfied", ascending=False)
satisfaction_ranked['rank'] = range(1, len(satisfaction_ranked) + 1)
satisfaction_ranked
# Out:
#                                     Neighborhood  \
# 45                  North Side: North Shore Area
# 27                                        Esplen
# 51                                       Oakwood
# 4                               Allegheny Center
# 54  Regent Square and Frick Park - Regent Square
# ..                                           ...
# 6                                      Allentown
# 20                              Duquesne Heights
# 62                              St Clair Village
# 47              North Side: Pleasant Valley Area
# 16                                Chartiers City
#
#     public_transportation_satisfied  public_transportation_dissatisfied  \
# 45                              100                                   0
# 27                               91                                   5
# 51                               90                                   0
# 4                                88                                   6
# ...

# %% [markdown]
# It appears that our top four neighborhoods **aren't in the top 10** of the satisfaction rankings. Let's explore their actual satisfaction rankings.

# %%
neighborhoods = ['Friendship','Oakland','East Liberty','Shadyside']

satisfaction_ranked[satisfaction_ranked.Neighborhood.isin(neighborhoods)][['Neighborhood','rank']]
# Out:
#     Neighborhood  rank
# 55     Shadyside    12
# 22  East Liberty    18
# 50       Oakland    34

# %% [markdown]
# Unfortunately <span style="color:#1b4537"><b>Friendship</b></span> isn't in the satisfaction dataset, which is understandable, since this dataset also only contains 71 entries of data.
#
# Overall, our third and fourth neighborhood, <span style="color:#649dc5"><b>East Liberty</b></span> and <span style="color:#80acce"><b>Shadyside</b></span>, are ranked 18 and 12 respectively, which *aren't too far off* from the expectations based on satisfaction, which means our data analysis was not for naught (or was it???)! <span style="color:#5c98c1">Oakland</span> is understandably more far-off because our second neighborhood is actually <span style="color:#5c98c1"><b>North</b> Oakland</span>.

# %% [markdown]
# # Data Analysis
#
# We will examine the three sub-heuristics in the following order:
# 1. [Bus stop density by neighborhood](#Bus-stop-density-by-neighborhood)
# 2. [Bus stop usage by neighborhood](#Bus-stop-usage-by-neighborhood)
# 3. [Average bus ridership by neighborhood](#Average-bus-ridership-by-neighborhood)
#
# Click to jump to your section of choice! However, take note that to reach an informed decision one must ultimately read all sections. I personally recommend perusing this in the above order, since much of the groundwork that is used to vastly aid the second and third sections is covered in the first section. *Also, the analyses in the second and third sections use some dataframes from the first.*

# %% [markdown]
# ## Bus stop density by neighborhood
#
# Let's dive into the data analysis! First, we need to load the data, and we will do so by first **streaming** the relevant data from the WPRDC website. Let's take a look at both the data *dictionary* (which gives us useful information about the dataset fields) and the dataset.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# dictionary
dictTS  = pd.read_csv("https://data.wprdc.org/datastore/dump/0a26e18e-f78b-43d2-8c75-2498ae255ecf")

dictTS
# Out:
#          Field                 Description
# 0   InternalID                          ID
# 1         Name                   Stop Name
# 2   ExternalID                 External ID
# 3    Direction                   Direction
# 4          Lat     Latitude (y Coordinate)
# 5         Long    Longitude (x coordinate)
# 6   Time_Point  Is this stop a time point?
# 7      NewZone               New Fare Zone
# 8   No_Rts_Ser  Routes served by this stop
# 9   Routes_161                      Routes
# 10        Mode                        Mode
# 11  Public_She                     Shelter
# 12  Public_Sto            Stop description

# %%
mapTS = gpd.read_file("transit_stops/PAAC_Stops_1909.shp") # read in the shapefile

# recreate 'geometry' column with Latitude and Longitude data to match geometry formatting of neighborhoods shapefile
mapTS = gpd.GeoDataFrame(mapTS, geometry=gpd.points_from_xy(mapTS.Longitude, mapTS.Latitude))

mapTS.head()
# Out:
#    StopID                            Stop_name  CleverID Direction Timepoint  \
# 0  E00175  26TH ST AT PENN AVE FS (SPRING WAY)    2593.0   Inbound         N
# 1  E00180               28TH ST AT LIBERTY AVE    2161.0   Inbound         N
# 2  E00270                32ND ST AT SPRING WAY    2410.0  Outbound         N
# 3  E00420                 40TH ST AT BUTLER ST    1199.0  Outbound         N
# 4  E00430            40TH ST AT DAVIDSON ST FS   20106.0  Outbound         N
#
#    Routes_ser  Routes_cou   Latitude  Longitude Mode     Shelter Stop_type  \
# 0  54, 88, 91         3.0  40.454635 -79.978170  Bus  No Shelter  Bus Stop
# 1          54         1.0  40.456288 -79.974651  Bus  No Shelter  Bus Stop
# 2  54, 88, 91         3.0  40.460347 -79.969436  Bus  No Shelter  Bus Stop
# 3          93         1.0  40.468655 -79.962115  Bus  No Shelter  Bus Stop
# 4          93         1.0  40.467676 -79.960929  Bus  No Shelter  Bus Stop
#
# ...

# %%
mapTS[['Stop_name', 'Latitude','Longitude','geometry']]
# Out:
#                                 Stop_name   Latitude  Longitude  \
# 0     26TH ST AT PENN AVE FS (SPRING WAY)  40.454635 -79.978170
# 1                  28TH ST AT LIBERTY AVE  40.456288 -79.974651
# 2                   32ND ST AT SPRING WAY  40.460347 -79.969436
# 3                    40TH ST AT BUTLER ST  40.468655 -79.962115
# 4               40TH ST AT DAVIDSON ST FS  40.467676 -79.960929
# ...                                   ...        ...        ...
# 6941        WASHINGTON RD AT CONSOL DR FS  40.345641 -80.057725
# 6942       VILLAGE DR AT WASHINGTON RD FS  40.342759 -80.059715
# 6943              SHIRE PL AT BREINING ST  40.388372 -80.007092
# 6944           KANE BLVD AT BOWER HILL RD  40.371747 -80.082735
# 6945                    BOGGS AVE AT #304  40.425492 -80.008430
#
#                         geometry
# 0     POINT (-79.97817 40.45464)
# 1     POINT (-79.97465 40.45629)
# 2     POINT (-79.96944 40.46035)
# 3     POINT (-79.96211 40.46865)
# ...

# %%
# filter out non-"Bus Stops"
mapTS = mapTS[mapTS["Stop_type"] == "Bus Stop"]

plt.style.use('dark_background')
mapTS.plot(figsize=(12,8)) # plot the geopandas dataframe

# %%
# load neighborhoods location data
neighborhoods = gpd.read_file("neighborhoods/Neighborhoods_.shp") # read in the shapefile

neighborhoods.plot(column='area', 
                   cmap='OrRd', 
                   edgecolor='orange', 
                   legend=True,
                   legend_kwds={'label':'Neighborhood Size'},
                   figsize=(12,8)) # plot the geopandas dataframe

# %%
neighborhoods[['hood', 'area', 'perimeter', 'geometry']]
# Out:
#                     hood        area  perimeter  \
# 0        Central Oakland   7843108.0  11526.863
# 1          North Oakland  13904629.0  20941.387
# 2           West Oakland   5999801.5  18271.426
# 3       Crawford-Roberts   7202139.0  15696.759
# 4         Strip District  16947852.0  23903.078
# ..                   ...         ...        ...
# 85             Ridgemont  10278895.0  16268.131
# 86              West End   5579501.0  18776.656
# 87  California-Kirkbride   6050988.0  11711.301
# 88            Glen Hazel  12713036.0  18931.703
# 89           Perry North         NaN        NaN
#
#                                              geometry
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1   POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2   POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3   POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4   POLYGON ((-79.97494 40.45629, -79.97484 40.456...
# ..                                                ...
# ...

# %% [markdown]
# We want to classify the bus stops into their respective neighborhoods. Thankfully, we can do this easily using the **geopandas** library's *spatial join "sjoin"* method with the *\"contains*\" operation. This means we are checking to see which bus stops each neighborhood "contains". Looking at the new *joint* dataframe we can see that each bus stop is now associated with a **hood**, which is exactly what we want.

# %%
# TSgeodf = gpd.GeoDataFrame.from_file("transit_stops/PAAC_Stops_1909.shp")
mapTS.crs = "epsg:4326"
# hoods = gpd.GeoDataFrame.from_file("neighborhoods/Neighborhoods_.shp")
neighborhoods.crs = "epsg:4326"

hoods_TS = gpd.sjoin(neighborhoods, mapTS, op="contains")

# print(TSwithHoods.columns)
hoods_TS = hoods_TS[['hood','Stop_name','geometry']]
hoods_TS
# Out:
#                hood                        Stop_name  \
# 0   Central Oakland      FORBES AVE AT BOUQUET ST FS
# 0   Central Oakland         FIFTH AVE AT OAKLAND AVE
# 0   Central Oakland      BLVD OF ALLIES AT DAWSON ST
# 0   Central Oakland        BLVD OF ALLIES AT WARD ST
# 0   Central Oakland       BLVD OF ALLIES AT BATES ST
# ..              ...                              ...
# 89      Perry North     MCKNIGHT RD OPP EVERGREEN RD
# 89      Perry North    PERRYSVILLE AVE OPP CONNIE DR
# 89      Perry North      IVORY AVE OPP NELSON RUN RD
# 89      Perry North   RODENBAUGH AVE AT IVORY AVE FS
# 89      Perry North  IVORY AVE OPP RODENBAUGH AVE FS
#
#                                              geometry
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0   POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# ...

# %% [markdown]
# Now, our goal is to count the number of entries for each unique neighborhood (row index). Hence we use the *groupby* method and reset the indices. Then we **merge** our new dataframe with our *Neighborhoods* dataframe, and trim it to get the Area column, then we are ready to analyze the bus stop density per neighborhood!

# %%
# group bus stops by neighborhood and create new dataframe of neighborhoods and bus stop counts
grouped_hoods_TS = hoods_TS.groupby("hood").size()
hoods_TScounts = grouped_hoods_TS.to_frame().reset_index()
hoods_TScounts.columns = ['Neighborhood','Stop_count']

hoods_TScounts = hoods_TScounts.merge(neighborhoods, how="inner", left_on="Neighborhood", right_on="hood")
hoods_TScounts.rename(columns = {'area':'Area'}, inplace = True)
hoods_TScounts = hoods_TScounts[['Neighborhood','Stop_count','Area','geometry']]
hoods_TScounts.head(10)
# Out:
#         Neighborhood  Stop_count        Area  \
# 0   Allegheny Center          21   5840713.0
# 1     Allegheny West          10   3938870.2
# 2          Allentown          23   8221419.5
# 3          Arlington          11  13108599.0
# 4         Banksville          10  27009770.0
# 5  Bedford Dwellings          11   4997335.5
# 6          Beechview          12  40706528.0
# 7        Beltzhoover          41  11723429.0
# 8         Bloomfield          81  19572930.0
# 9              Bluff          26   9127700.0
#
#                                             geometry
# 0  POLYGON ((-80.00149 40.45270, -80.00146 40.452...
# 1  POLYGON ((-80.01457 40.45397, -80.01453 40.453...
# 2  POLYGON ((-79.99967 40.42813, -79.99961 40.428...
# 3  POLYGON ((-79.95773 40.41871, -79.95769 40.418...
# 4  POLYGON ((-80.02969 40.42127, -80.02976 40.419...
# 5  POLYGON ((-79.96568 40.45367, -79.96525 40.453...
# 6  POLYGON ((-80.02121 40.42342, -80.02111 40.423...
# ...

# %% [markdown]
# Before we dive into calculating the bus stop density per neighborhood, let's figure out what *units* the areas are in, since there is no comprehensive data dictionary on the WPRDC website for the Neighborhoods data with this information. To determine the units of representation I calculated the total of all areas which summed up to **1,423,950,712** and converted this number from different area units to square miles to compare it with Pittsburgh's total land area of **58.34 square miles**, and ascertained that it is in **square feet**. Hence I used the conversion factor of **2.788 * 10\*\*7** to convert the area to square miles.
#
# Note: **ONLY RUN THE BELOW CELL ONCE.**

# %%
# calculated total of all areas to guess and determine what units the areas are in
# hoods_TScounts['Area'].sum()

# convert area column to square miles
hoods_TScounts['Area'] = hoods_TScounts['Area'] / (2.788*10**7)

# create bus stop density (per square mile) column
hoods_TScounts['Stop_density'] = hoods_TScounts['Stop_count'] / hoods_TScounts['Area']

# %%
hoods_TSdensity = hoods_TScounts.sort_values(by=['Stop_density'], ascending=False)
hoods_TSdensity
# Out:
#                 Neighborhood  Stop_count      Area  \
# 45  Lincoln-Lemington-Belmar          89  0.280106
# 48        Marshall-Shadeland          40  0.230500
# 85              West Oakland          32  0.215201
# 32                Friendship          14  0.106218
# 71             Spring Garden          34  0.274508
# ..                       ...         ...       ...
# 6                  Beechview          12  1.460062
# 79            Swisshelm Park           3  0.479907
# 53             New Homestead           3  0.794303
# 36                      Hays           6  1.750384
# 59               Perry North          38       NaN
#
#                                              geometry  Stop_density
# 45  MULTIPOLYGON (((-79.90496 40.48522, -79.90464 ...    317.736848
# 48  MULTIPOLYGON (((-80.02568 40.48276, -80.02498 ...    173.535508
# 85  POLYGON ((-79.96230 40.44294, -79.96220 40.442...    148.698253
# 32  POLYGON ((-79.93095 40.46304, -79.93098 40.462...    131.804230
# ...

# %% [markdown]
# ONE issue. Perry North's area is *NaN* so its density is *NaN*. Let's fill in Perry North's area data obtained from a quick web search. :)

# %%
hoods_TSdensity.loc[hoods_TSdensity['Neighborhood'] == 'Perry North', 'Area'] = 1.212
hoods_TSdensity.loc[hoods_TSdensity['Neighborhood'] == 'Perry North', 'Stop_density'] = hoods_TSdensity.loc[hoods_TSdensity['Neighborhood'] == 'Perry North', 'Stop_count'] / hoods_TSdensity.loc[hoods_TSdensity['Neighborhood'] == 'Perry North', 'Area']

# re-sort
hoods_TSdensity = hoods_TSdensity.sort_values(by=['Stop_density'], ascending=False)
hoods_TSdensity
# Out:
#                 Neighborhood  Stop_count      Area  \
# 45  Lincoln-Lemington-Belmar          89  0.280106
# 48        Marshall-Shadeland          40  0.230500
# 85              West Oakland          32  0.215201
# 32                Friendship          14  0.106218
# 71             Spring Garden          34  0.274508
# ..                       ...         ...       ...
# 58                 Overbrook           7  0.839074
# 6                  Beechview          12  1.460062
# 79            Swisshelm Park           3  0.479907
# 53             New Homestead           3  0.794303
# 36                      Hays           6  1.750384
#
#                                              geometry  Stop_density
# 45  MULTIPOLYGON (((-79.90496 40.48522, -79.90464 ...    317.736848
# 48  MULTIPOLYGON (((-80.02568 40.48276, -80.02498 ...    173.535508
# 85  POLYGON ((-79.96230 40.44294, -79.96220 40.442...    148.698253
# 32  POLYGON ((-79.93095 40.46304, -79.93098 40.462...    131.804230
# ...

# %% [markdown]
# Sweet! Now that that's cleared and out of the way, we can easily see which neighborhoods are in the lead in this aspect of stop density. Seems like Lincoln-Lemington-Belmar clearly leads the pack in this one. To see just how much the disparity between **Lincoln-Lemington-Belmar** and the rest of the neighborhoods is, as well as how *each neighborhood compares with the rest*, let's convert our density dataframe to a *GeoDataFrame* and plot it on a <span style="color:purple"><b>colorful</b></span> map by density!

# %%
# convert to geodataframe
density = gpd.GeoDataFrame(hoods_TSdensity, geometry='geometry')

print(density[['Neighborhood','Stop_density']])

density.plot(column='Stop_density', 
             cmap='BuPu', 
             edgecolor='lightblue', 
             legend=True,
             legend_kwds={'label':'Bus Stop Density'},
             figsize=(12,8)
            )# plot the geopandas dataframe
# Out:
#                 Neighborhood  Stop_density
# 45  Lincoln-Lemington-Belmar    317.736848
# 48        Marshall-Shadeland    173.535508
# 85              West Oakland    148.698253
# 32                Friendship    131.804230
# 71             Spring Garden    123.858014
# ..                       ...           ...
# 58                 Overbrook      8.342528
# 6                  Beechview      8.218829
# 79            Swisshelm Park      6.251212
# 53             New Homestead      3.776897
# 36                      Hays      3.427819
#
# [88 rows x 2 columns]

# %% [markdown]
# So, there's that. <span style="color:#400a43"><b>Lincoln-Lemington-Belmar</b></span> and <span style="color:#8b8abb"><b>Marshall-Shadeland</b></span> are clearly in the lead for this one. They *passed* the preliminary round. Now let's examine more exciting data—on actual **ridership**. After all,
#
# *\"What's the point of so many bus stops if no one uses them?" - some <span style="color:#aac1da"><i>Hays</i></span> resident*
#
# Indeed. Let's investigate this.

# %% [markdown]
# ## Bus stop usage by neighborhood

# %%
# load transit stop usage data
usageTS = pd.read_csv("https://data.wprdc.org/datastore/dump/3115c0b9-b48a-49aa-8e39-fd318eb62c04")
# usageTS = gpd.GeoDataFrame(usageTS, geometry=gpd.points_from_xy(usageTS.LONGITUDE, usageTS.LATITUDE))

# display usageTS columns for reference
print(usageTS.columns)

# filter to only show data for bus stops
usageTS = usageTS[usageTS["STOP_TYPE"] == "Bus"]
usageTS = usageTS[['STOP_NAME','FY19_AVG_ON','FY19_AVG_OFF','FY19_AVG_TOTAL','FY19_RANK']]
# change column names
usageTS.columns = ['Stop_name','FY19_avg_on','FY19_avg_off','FY19_avg_total','FY19_rank']
usageTS
# Out:
# Index(['STOP_ID', 'ROUTE', 'STOP_ROUTE', 'STOP_NAME', 'CLEVER_ID', 'LATITUDE',
#        'LONGITUDE', 'ALL_ROUTES', 'SHELTER', 'STOP_TYPE', 'CURRENT_STOP',
#        'FY19_AVG_ON', 'FY19_AVG_OFF', 'FY19_AVG_TOTAL', 'FY19_RANK', '1806_ON',
#        '1806_OFF', '1809_ON', '1809_OFF', '1811_ON', '1811_OFF', '1903_ON',
#        '1903_OFF', '1906_ON', '1906_OFF'],
#       dtype='object')
#                           Stop_name  FY19_avg_on  FY19_avg_off  \
# 0        SMITHFIELD ST AT SIXTH AVE         3408          1737
# 1            LIBERTY AVE AT 10TH ST          877          2257
# 2          STANWIX ST AT FORBES AVE         1245           828
# 3                7TH ST AT PENN AVE          732          1140
# 4            LIBERTY AVE AT WOOD ST         1310           431
# ...                             ...          ...           ...
# 11896  WATERFRONT DR AT LOEWS THEAT            0             0
# 11897   WATERFRONT DR AT RECREATION            0             0
# ...

# %% [markdown]
# Now, since we have already matched each bus stop to their neighborhood we will take advantage of this and *merge* our existing data sets instead of going through the whole *sjoin* process again.

# %%
hoods_TSusage = usageTS.merge(hoods_TS, how="inner", on="Stop_name")

hoods_TSusage.rename(columns = {'hood':'Neighborhood'}, inplace = True)
hoods_TSusage[['Neighborhood','Stop_name','FY19_avg_on','FY19_avg_off','FY19_avg_total','FY19_rank','geometry']]
# Out:
#                    Neighborhood                     Stop_name  FY19_avg_on  \
# 0     Central Business District      STANWIX ST AT FORBES AVE         1245
# 1     Central Business District      STANWIX ST AT FORBES AVE          223
# 2     Central Business District            7TH ST AT PENN AVE          732
# 3     Central Business District            7TH ST AT PENN AVE          402
# 4     Central Business District            7TH ST AT PENN AVE          228
# ...                         ...                           ...          ...
# 4286                    Larimer     HAMILTON AVE AT PUTNAM ST            0
# 4287   Lincoln-Lemington-Belmar       JOB CORPS DR OPP ARMORY            0
# 4288   Lincoln-Lemington-Belmar  LEMINGTON AVE AT PAULSON AVE            0
# 4289        Squirrel Hill South       SHADY AVE OPP HOBART ST            0
# 4290   Lincoln-Lemington-Belmar          WILTSIE ST OPP #6903            0
#
#       FY19_avg_off  FY19_avg_total  FY19_rank  \
# ...

# %% [markdown]
# Instead of counting the number of bus stops each neighborhood has, it makes much more sense here to <i>tabulate the ranks of all the bus stops in each neighborhood and then get the **average rankings**</i>. Then we aim to rank the neighborhoods based on their average bus stop usage rankings.

# %%
# group bus stops by neighborhood and create new dataframe of neighborhoods and TS usage data
grouped_hoods_TSusage = hoods_TSusage.groupby("Neighborhood")["FY19_rank"].mean().to_frame()

usage = grouped_hoods_TSusage.sort_values(by=['FY19_rank'])
usage.rename(columns = {'FY19_rank':'2019_average_usage'}, inplace = True)
usage
# Out:
#                            2019_average_usage
# Neighborhood
# North Oakland                     1657.543353
# Central Oakland                   1757.464789
# Central Business District         1775.322404
# Bedford Dwellings                 1809.500000
# Friendship                        2199.250000
# ...                                       ...
# Beechview                         9141.000000
# South Shore                       9259.800000
# Overbrook                         9562.470588
# Esplen                            9571.736842
# Allegheny West                   10084.166667
#
# [87 rows x 1 columns]

# %% [markdown]
# ...more color? More visuals? Coming right up!

# %%
usage_gdf = usage.merge(hoods_TSusage[['Neighborhood','geometry']],on="Neighborhood", how="left")
usage_gdf= gpd.GeoDataFrame(usage_gdf, geometry='geometry')

# hax to invert rankings to display on map
usage_gdf[['2019_average_usage']] = 1 / usage_gdf[['2019_average_usage']]

# %%
usage_gdf.plot(column='2019_average_usage', 
           cmap='GnBu', 
           edgecolor='lightblue', 
           legend=True,
           legend_kwds={'label':'2019 Average Usage'},
           figsize=(12,8)
          )# plot the geopandas dataframe

# %% [markdown]
# Aaaaand... results are in! It seems like <span style="color:#19417d"><b>North Oakland</b></span> wins this one! If you observe it more closely, it makes sense that <span style="color:#245a97"><b>Central Business District</b></span> is one of the top three. <span style="color:#19417d"><b>North Oakland</b></span> and <span style="color:#225793"><b>Central Oakland</b></span> also make sense because they are the busier school districts. After all, Pittsburgh **is** a *school city*.

# %% [markdown]
# ## Average bus ridership by neighborhood

# %% [markdown]
# Let's load the **usage** dataset again. We're going to need it as firepower for our last stretch. In particular, we are interested in the "ROUTE" column.

# %%
usage_data = pd.read_csv("https://data.wprdc.org/datastore/dump/3115c0b9-b48a-49aa-8e39-fd318eb62c04")
usage_data
# Out:
#       STOP_ID ROUTE  STOP_ROUTE                     STOP_NAME  CLEVER_ID  \
# 0      P03090    P1   P03090_P1    SMITHFIELD ST AT SIXTH AVE     7280.0
# 1      P02325    P1   P02325_P1        LIBERTY AVE AT 10TH ST     7279.0
# 2      P03360    38   P03360_38      STANWIX ST AT FORBES AVE       44.0
# 3      P00930    16   P00930_16            7TH ST AT PENN AVE    20182.0
# 4      P02550    91   P02550_91        LIBERTY AVE AT WOOD ST       46.0
# ...       ...   ...         ...                           ...        ...
# 11896  S48270   53L  S48270_53L  WATERFRONT DR AT LOEWS THEAT    17824.0
# 11897  S48275    59   S48275_59   WATERFRONT DR AT RECREATION    20379.0
# 11898  S48257    59   S48257_59  WATERFRONT DR OPP COMMONWEAL    15853.0
# 11899  E59010   P67  E59010_P67  WILLIAM PENN HWY OPP CHURCHI     7896.0
# 11900  E70947   P67  E70947_P67          WM PENN HWY AT #2295     7897.0
#
#         LATITUDE  LONGITUDE                        ALL_ROUTES  \
# ...

# %% [markdown]
# Now, our *main* firepower:

# %%
# load average ridership data
ridershipTS = pd.read_csv("https://data.wprdc.org/datastore/dump/12bb84ed-397e-435c-8d1b-8ce543108698")

# display usageTS columns for reference
print(ridershipTS.columns)

# filter to only show data for bus stops
ridershipTS = ridershipTS[ridershipTS["mode"] == "Bus"]
ridershipTS
# Out:
# Index(['route', 'ridership_route_code', 'route_full_name', 'current_garage',
#        'mode', 'month_start', 'year_month', 'day_type', 'avg_riders',
#        'day_count'],
#       dtype='object')
#      route ridership_route_code            route_full_name current_garage  \
# 0        1                  001          1 - FREEPORT ROAD           Ross
# 1        4                  004              4 - TROY HILL           Ross
# 2        6                  006            6 - SPRING HILL           Ross
# 3        8                  008            8 - PERRYSVILLE           Ross
# 4       11                  011              11 - FINEVIEW           Ross
# ...    ...                  ...                        ...            ...
# 8347    Y1                   Y1           Y1 - LARGE FLYER   West Mifflin
# 8348   Y45                  Y45  Y45 - BALDWIN MANOR FLYER   West Mifflin
# 8349   Y46                  Y46      Y46 - ELIZABETH FLYER   West Mifflin
# ...

# %% [markdown]
# This dataset describes the **average ridership per route** in Pittsburgh. Ultimately, we want to describe the average ridership **per neighborhood**. How do we achieve this? Read on to find out!
#
# So first of, we want to match neighborhoods to routes. How? We first match **neighborhoods** to **bus stops**! Luckily for you (and me), we have already done that in the first section! *(Sorry if you're here before looking at the first section, please scroll up (or CTRL+F/CMD+F) to the loading and manipulation of hoods_TS)* As a quick refresher let's take a peek at the *hoods_TS* and *usage_data* dataframes that we are about to **merge**.

# %%
hoods_TS.head()
# Out:
#               hood                    Stop_name  \
# 0  Central Oakland  FORBES AVE AT BOUQUET ST FS
# 0  Central Oakland     FIFTH AVE AT OAKLAND AVE
# 0  Central Oakland  BLVD OF ALLIES AT DAWSON ST
# 0  Central Oakland    BLVD OF ALLIES AT WARD ST
# 0  Central Oakland   BLVD OF ALLIES AT BATES ST
#
#                                             geometry
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...

# %%
usage_data.head()
# Out:
#   STOP_ID ROUTE STOP_ROUTE                   STOP_NAME  CLEVER_ID   LATITUDE  \
# 0  P03090    P1  P03090_P1  SMITHFIELD ST AT SIXTH AVE     7280.0  40.441550
# 1  P02325    P1  P02325_P1      LIBERTY AVE AT 10TH ST     7279.0  40.443739
# 2  P03360    38  P03360_38    STANWIX ST AT FORBES AVE       44.0  40.440989
# 3  P00930    16  P00930_16          7TH ST AT PENN AVE    20182.0  40.443298
# 4  P02550    91  P02550_91      LIBERTY AVE AT WOOD ST       46.0  40.442401
#
#    LONGITUDE                        ALL_ROUTES            SHELTER STOP_TYPE  \
# 0 -79.997761  39, 40, 44, 87, P1, P2, P68, P71  Envision Downtown       Bus
# 1 -79.995153  39, 40, 44, 87, P1, P2, P68, P71  Envision Downtown       Bus
# 2 -80.003966                            36, 38         No Shelter       Bus
# 3 -80.000402                        13, 16, 17         No Shelter       Bus
# 4 -79.999575               28X, 77, 86, 88, 91         No Shelter       Bus
#
# ...

# %% [markdown]
# Let's *left* merge the two on the bus stops (i.e. "**Stop_name**"). Here, we *left* merge so that we only keep the *hoods_TS* columns that we are more interested in.

# %%
hoods_routes = hoods_TS.merge(usage_data[['STOP_NAME','ROUTE']],left_on="Stop_name", right_on="STOP_NAME")
hoods_routes.rename(columns = {'hood':'Neighborhood', 'ROUTE':'route'}, inplace = True)
hoods_routes = hoods_routes.drop(columns=['STOP_NAME'])

hoods_routes
# Out:
#          Neighborhood                     Stop_name  \
# 0     Central Oakland   FORBES AVE AT BOUQUET ST FS
# 1     Central Oakland   FORBES AVE AT BOUQUET ST FS
# 2     Central Oakland   FORBES AVE AT BOUQUET ST FS
# 3     Central Oakland   FORBES AVE AT BOUQUET ST FS
# 4     Central Oakland   FORBES AVE AT BOUQUET ST FS
# ...               ...                           ...
# 4286      Perry North      PERRYSVILLE AVE AT #3835
# 4287      Perry North    EVERGREEN RD AT BAYTREE ST
# 4288      Perry North    PERRYSVILLE AVE AT EAST ST
# 4289      Perry North  MCKNIGHT RD OPP EVERGREEN RD
# 4290      Perry North   IVORY AVE OPP NELSON RUN RD
#
#                                                geometry route
# 0     POLYGON ((-79.95304 40.44203, -79.95302 40.442...   61D
# 1     POLYGON ((-79.95304 40.44203, -79.95302 40.442...   61C
# 2     POLYGON ((-79.95304 40.44203, -79.95302 40.442...   61A
# 3     POLYGON ((-79.95304 40.44203, -79.95302 40.442...   61B
# ...

# %% [markdown]
# Sweet! Now we have a dataframe that matches each neighborhood to the bus routes it has. Next we want to *merge* this neighborhood-routes dataframe with the *ridershipTS* dataframe that we loaded in earlier to examine the **avg_riders** data column for each neighborhood.

# %%
hoods_routeriders = hoods_routes.merge(ridershipTS[['route','year_month','day_type','avg_riders','day_count']],on="route")

hoods_routeriders = hoods_routeriders.sort_values(by=["avg_riders"], ascending=False)
hoods_routeriders
# Out:
#                      Neighborhood                    Stop_name  \
# 286147  Central Business District  GRANT ST AT US STEEL STOP A
# 286258  Central Business District      GRANT ST AT POST OFFICE
# 286294  Central Business District      GRANT ST AT POST OFFICE
# 286183  Central Business District  GRANT ST AT US STEEL STOP A
# 286246  Central Business District      GRANT ST AT POST OFFICE
# ...                           ...                          ...
# 409874             Swisshelm Park      WHIPPLE ST AT NEVADA ST
# 409910             Swisshelm Park  COMMERCIAL ST AT WHIPPLE ST
# 409873             Swisshelm Park      WHIPPLE ST AT NEVADA ST
# 409947              Regent Square      PEEBLES ST OPP GREEN ST
# 409836               Point Breeze     PEEBLES ST AT FORBES AVE
#
#                                                  geometry route  year_month  \
# 286147  POLYGON ((-79.99238 40.44484, -79.99233 40.444...    P1      201709
# ...

# %% [markdown]
# Then once again we *groupby* "Neighborhood" and take the average of the **daily average ridership per neighborhood**. Take note that here, I have simplified the problem by taking the daily average ridership across both *weekdays* and *weekends* treating them as equal; in effect I am saying that my ridership heuristic includes weekend ridership. And this is a perfectly sound heuristic. Ultimately it just depends on what you value more—since I chose the heuristic I have decided that weekend ridership is important in my determination of best neighborhood. *(I mean, if people don't even visit or at least pass by your neighborhood on weekends when they're the freest, how sad, really, is your neighborhood? JK.)*

# %%
# group bus stops by neighborhood and create new dataframe of neighborhoods and route ridership
grouped_hoods_ridership = hoods_routeriders.groupby("Neighborhood")["avg_riders"].mean().to_frame()

ridership = grouped_hoods_ridership.sort_values(by=['avg_riders'], ascending=False)
ridership.rename(columns = {'avg_riders':'Average_daily_riders'}, inplace = True)
ridership
# Out:
#                    Average_daily_riders
# Neighborhood
# Bluff                       3342.399469
# South Side Slopes           3159.481409
# South Shore                 3095.405405
# Regent Square               2966.962934
# Highland Park               2903.600038
# ...                                 ...
# Mount Washington             374.284310
# Swisshelm Park               335.243243
# Duquesne Heights             333.567568
# Fineview                     312.990991
# Allegheny West                95.756757
#
# [87 rows x 1 columns]

# %% [markdown]
# Ok. Data Analysis done. (**Bluff**!) *( See what I did there? ;) )* In all seriousness, from the above *ridership* dataframe it is already clear which neighborhood wins in ridership. But, you know the drill *(oops, not if you came to read this section first, sadly. What did I tell you? Huh, what did I tell you!?)*. We want *pretty*, **pretty** data visualization. *(Of course, that means a different color again)*

# %%
ridership.plot(kind='bar',figsize=(12,8))

# %% [markdown]
# ...ok no. Let's try again.

# %%
riders = ridership.merge(hoods_TS[['hood','geometry']],left_on="Neighborhood", right_on="hood", how="left")
riders = gpd.GeoDataFrame(riders, geometry='geometry')
riders.rename(columns = {'hood':'Neighborhood'}, inplace = True)

# %%
riders.plot(column='Average_daily_riders', 
           cmap='PuRd', 
           edgecolor='pink', 
           legend=True,
           legend_kwds={'label':'Average Daily Riders'},
           figsize=(12,8)
          )# plot the geopandas dataframe

# %% [markdown]
# Already we can tell that this is going to be the most *neutral* heuristic in our ultimate determination of the **best bus stop neighborhood** in Pittsburgh, seeing that the neighborhoods in contest are much closer in color shades than in the other two sections. Nonetheless, let's give <span style="color:#5e0e21"><b>The Bluff (Uptown)</b></span>, <span style="color:#731430"><b>South Side Slopes</b></span> and <span style="color:#791635"><b>South Shore</b></span> some *love* for knocking this one out of the park.
#
# Note that the winners from the second section, <span style="color:#b02952"><b>North Oakland</b></span>, <span style="color:#d54088"><b>Central Oakland</b></span>, and <span style="color:#d162a5"><b>Central Business District</b></span> are not too far off. However, <span style="color:#c48dbf"><b>Lincoln-Lemington-Belmar</b></span> and <span style="color:#c883b9"><b>Marshall-Shadeland</b></span> are pretty far-off from the rest evaluated by this heuristic.
#
# But... wait. Are we just going to decide based on this superficial, preliminary qualitative assessment that <span style="color:#b02952"><b>North Oakland</b></span> is the overall winner of all heuristics and therefore the **best bus stop neighborhood** in Pittsburgh? Can we just do this? No! What about <span style="color:#901d46"><b>Regent Square</b></span> or <span style="color:#8f1d45"><b>Highland Park</b></span>? Just because they are the fourth and fifth in this heuristic, does it mean we exclude them in the determination? If not, should we instead look at the top five? Then what about the sixth and seventh? Do we look at top ten? *At which point should we stop looking?* Also, should each heuristiic be **weighted** the same (33%), or should one be weighted more than the rest? Why?
#
# We embark on a further, more conclusive quantitative analysis.

# %% [markdown]
# ## Conclusion
#
# Let's bring back the *scoring table* from the beginning to refresh our memories.
#
# | Neighborhood      | Bus Stop Density  | Bus Stop Usage | Average Ridership |
# | ----------------- | ----------------- | -------------- | ----------------- |
# | Westwood          |                   |                |                   |
# | 31st ward         |                   |                |                   |
# | Arlington         |                   |                |                   |
# | Allegheny Center  |                   |                |                   |
# | Allegheny West    |                   |                |                   |
# | ...               |                   |                |                   |
# | Woods Run- Halls Grove |              |                |                   |
#
# We need to come up with **weights** to assign to each heuristic or *category*, before we tabulate the rankings of neighborhoods in each category and finally decide who comes out top.
#
# .
#
# .
#
# .
#
# So after *loooong* deliberation and *caaaareful* consideration, I have <del><i>entirely arbitrarily</i></del> come up with the following weighted heuristics:
# - Bus Stop Density **30%**
# - Bus Stop Usage **30%**
# - Average Ridership **40%**
#
# We first look at the individual dataframes from each heuristic, and rank them individually.

# %%
density['Bus Stop Density'] = range(1, len(density)+1)
density.drop(columns=['Stop_count','Area','geometry'])
# Out:
#                 Neighborhood  Stop_density  Bus Stop Density
# 45  Lincoln-Lemington-Belmar    317.736848                 1
# 48        Marshall-Shadeland    173.535508                 2
# 85              West Oakland    148.698253                 3
# 32                Friendship    131.804230                 4
# 71             Spring Garden    123.858014                 5
# ..                       ...           ...               ...
# 58                 Overbrook      8.342528                84
# 6                  Beechview      8.218829                85
# 79            Swisshelm Park      6.251212                86
# 53             New Homestead      3.776897                87
# 36                      Hays      3.427819                88
#
# [88 rows x 3 columns]

# %%
usage['Bus Stop Usage'] = range(1, len(usage) + 1)
usage
# Out:
#                            2019_average_usage  Bus Stop Usage
# Neighborhood
# North Oakland                     1657.543353               1
# Central Oakland                   1757.464789               2
# Central Business District         1775.322404               3
# Bedford Dwellings                 1809.500000               4
# Friendship                        2199.250000               5
# ...                                       ...             ...
# Beechview                         9141.000000              83
# South Shore                       9259.800000              84
# Overbrook                         9562.470588              85
# Esplen                            9571.736842              86
# Allegheny West                   10084.166667              87
#
# [87 rows x 2 columns]

# %%
ridership['Average Ridership'] = range(1, len(ridership) + 1)
ridership
# Out:
#                    Average_daily_riders  Average Ridership
# Neighborhood
# Bluff                       3342.399469                  1
# South Side Slopes           3159.481409                  2
# South Shore                 3095.405405                  3
# Regent Square               2966.962934                  4
# Highland Park               2903.600038                  5
# ...                                 ...                ...
# Mount Washington             374.284310                 83
# Swisshelm Park               335.243243                 84
# Duquesne Heights             333.567568                 85
# Fineview                     312.990991                 86
# Allegheny West                95.756757                 87
#
# [87 rows x 2 columns]

# %%
# create new dataframe as in scoring table, using density as basis
scores = density[['Neighborhood','Bus Stop Density']]
# merge with usage and ridership data
scores = pd.merge(scores, usage.drop(columns=['2019_average_usage']), on='Neighborhood')
scores = pd.merge(scores, ridership.drop(columns=['Average_daily_riders']), on='Neighborhood')

scores
# Out:
#                 Neighborhood  Bus Stop Density  Bus Stop Usage  \
# 0   Lincoln-Lemington-Belmar                 1              58
# 1         Marshall-Shadeland                 2              15
# 2               West Oakland                 3              59
# 3                 Friendship                 4               5
# 4              Spring Garden                 5              81
# ..                       ...               ...             ...
# 82                 Overbrook                84              85
# 83                 Beechview                85              83
# 84            Swisshelm Park                86              71
# 85             New Homestead                87              72
# 86                      Hays                88              46
#
#     Average Ridership
# 0                  44
# 1                  40
# 2                  13
# 3                  12
# 4                  78
# ..                ...
# 82                 67
# ...

# %% [markdown]
# **Weigh** results from the individual heuristics.

# %%
weights = [0.3, 0.3, 0.4]
scores['Density weighted'] = scores['Bus Stop Density'] * weights[0]
scores['Usage weighted'] = scores['Bus Stop Usage'] * weights[1]
scores['Ridership weighted'] = scores['Average Ridership'] * weights[2]
scores['Total Weighted Ranking'] = scores['Density weighted'] + scores['Usage weighted'] + scores['Ridership weighted']

scores = scores.sort_values(by=['Total Weighted Ranking'])
scores
# Out:
#         Neighborhood  Bus Stop Density  Bus Stop Usage  Average Ridership  \
# 3         Friendship                 4               5                 12
# 29     North Oakland                30               1                  7
# 10      East Liberty                11              11                 15
# 26         Shadyside                27               6                 11
# 6         Bloomfield                 7              10                 26
# ..               ...               ...             ...                ...
# 77  Duquesne Heights                78              63                 85
# 82         Overbrook                84              85                 67
# 83         Beechview                85              83                 70
# 79        Banksville                81              80                 76
# 84    Swisshelm Park                86              71                 84
#
#     Density weighted  Usage weighted  Ridership weighted  \
# ...

# %%
scores.drop(columns=['Total Weighted Ranking','Bus Stop Density','Bus Stop Usage', 'Average Ridership']).plot(x='Neighborhood', 
                                                                                                              kind="bar", 
                                                                                                              stacked=True,
                                                                                                              figsize=(15,10)
                                                                                                             )

# %% [markdown]
# Sweeeeeet. Stacked bar charts work great here because we can obtain all the information we need at a glance to make an informed decision about which neighborhood deserves the title of the **best bus stop neighborhood in Pittsburgh**. However, the above visualization is so cluttered particularly because we have so many neighborhoods. Let's *trim* it down to only show the top few neighborhoods in contest for the top spot.

# %%
plt.style.use('seaborn-pastel')
scores.head(10).drop(columns=['Total Weighted Ranking','Density weighted','Usage weighted','Ridership weighted']).plot(x='Neighborhood', 
                                                                                                                       kind="bar",
                                                                                                                       stacked=True,
                                                                                                                       figsize=(10,6)
                                                                                                                      )

# %% [markdown]
# Note that this plot is of *'Bus Stop Density'*, *'Bus Stop Usage'* and *'Average Ridership'* rankings **before being weighted**! Still, it is clear that **Friendship**, **North Oakland**, **East Liberty** and **Shadyside** stand out here.
#
# Let's take a look at the actual weighted data and rankings.

# %%
plt.style.use('dark_background')
scores.head(10).drop(columns=['Total Weighted Ranking','Bus Stop Density','Bus Stop Usage', 'Average Ridership']).plot(x='Neighborhood', 
                                                                                                                       kind="bar",
                                                                                                                       stacked=True,
                                                                                                                       figsize=(10,6)
                                                                                                                      )

# %% [markdown]
# Alas, the overall **best bus stop neighborhoods** in Pittsburgh are:
# 1. Friendship
# 2. North Oakland
# 3. East Liberty
# 4. Shadyside
#
# Let's see our results on one last <span style="color:lightblue"><b>pretty</b></span> map, shall we? ;)

# %%
scores['Overall'] = 1 / scores['Total Weighted Ranking']

scores = scores.merge(hoods_TSusage[['Neighborhood','geometry']], how="outer", on="Neighborhood")
scores = gpd.GeoDataFrame(scores, geometry='geometry')

# %%
scores.plot(column='Overall', 
            cmap='PuBuGn', 
            edgecolor='lightblue', 
            legend=True,
            legend_kwds={'label':'Overall Bus Stop Ranking'},
            figsize=(12,8)
           )# plot the geopandas dataframe

# %% [markdown]
# Aaaand... <span style="color:#1b4537"><b>Friendship</b></span> clearly wins.
#
# Does this match up with our expectations?
